# %%
import os
import glob
import pandas as pd
from collections import Counter

# %%
def count_to_tpm(count_df, gene_lengths):
    rpk = count_df.div(gene_lengths, axis=0)
    scaling_factor = rpk.sum(axis=0)
    tpm = rpk.div(scaling_factor, axis=1) * 1e6
    return tpm

def tpm_to_count(tpm_df, gene_lengths):
    common_genes = tpm_df.index.intersection(gene_lengths.index)
    tpm_df = tpm_df.loc[common_genes]
    gene_lengths = gene_lengths.loc[common_genes]
    rpk = tpm_df.multiply(gene_lengths, axis=0) / 1000
    scaling_factors = rpk.sum(axis=0) / 1e6
    count_df = rpk.divide(scaling_factors, axis=1)
    count_df = count_df.round().astype(int)
    return count_df

# %%
xls_files = glob.glob("GS*.xlsx")
tsv_files = glob.glob("GS*.tsv")
csv_files = glob.glob("GS*.csv")
all_files = xls_files + tsv_files + csv_files
all_files
# Out:
# ['GSE139889.xlsx',
#  'GSE119629.tsv',
#  'GSE150642.tsv',
#  'GSM8291018.csv',
#  'GSM8291019.csv',
#  'GSM8291020.csv',
#  'GSM8291021.csv',
#  'GSM8291022.csv']

# %%
gene_lengths = pd.read_csv("gene_lengths.csv", index_col=0).squeeze()

# %%
dataframes = []

for idx, file in enumerate(all_files):
    print(f"Processing file {idx}: {file}")

    if file.endswith(".xlsx"):
        df = pd.read_excel(file)
    elif file.endswith(".csv"):
        df = pd.read_csv(file)
    elif file.endswith(".tsv"):
        df = pd.read_csv(file, sep="\t")
    else:
        continue
        
    sample_cols = [col for col in df.columns if col.startswith("S")]
    df = df[["GeneID"] + sample_cols].drop_duplicates(subset="GeneID")
    df.set_index("GeneID", inplace=True)

    if idx < 2:
        try:
            df = tpm_to_count(df, gene_lengths)
        except Exception as e:
            print(f"Error converting to TPM in file {file}: {e}")
            continue
    df.columns = [f"{col}_file{idx}" for col in df.columns]
    dataframes.append(df)
    
dataframes
# Out:
# Processing file 0: GSE139889.xlsx
# Processing file 1: GSE119629.tsv
# Processing file 2: GSE150642.tsv
# Processing file 3: GSM8291018.csv
# Processing file 4: GSM8291019.csv
# Processing file 5: GSM8291020.csv
# Processing file 6: GSM8291021.csv
# Processing file 7: GSM8291022.csv
# [             S1_file0  S2_file0  S3_file0  S4_file0  S5_file0  S6_file0  \
#  GeneID
#  FBgn0000003         1         2         7         5         1         3
#  FBgn0000008       114       167       308       185        87         7
#  FBgn0000014         0         0         0         0         0         0
#  FBgn0000015         0         0         0         0         0         0
#  FBgn0000017        71        84       176        12         0        87
#  ...               ...       ...       ...       ...       ...       ...
#  FBgn0287695         0         0         0         0         0        18
#  FBgn0287696         4         2         9         0        15         0
#  FBgn0287720         0         0         0         0         0         0
#  FBgn0287724         0         0         0         0         0         0
#  FBgn0287725         0        12        30         3         0        10
#
#               S7_file0  S8_file0  S9_file0  S10_file0  ...  S13_file0  \
#  GeneID                                                ...
#  FBgn0000003         2         4         1          5  ...          0
#  FBgn0000008        28        62       113         33  ...          0
#  FBgn0000014         0         0         0          0  ...          0
#  FBgn0000015         0         0         0          0  ...          0
#  FBgn0000017        46        51        79        110  ...         23
#  ...               ...       ...       ...        ...  ...        ...
#  FBgn0287695         9         0         0          0  ...          0
#  FBgn0287696         0         3         0          4  ...          2
#  FBgn0287720         0         0         0          0  ...          1
#  FBgn0287724         0         0         0          0  ...          0
#  FBgn0287725        12         8       116          6  ...         29
#
#               S14_file0  S15_file0  S16_file0  S17_file0  S18_file0  S19_file0  \
#  GeneID
#  FBgn0000003          0          0          0         10         24          1
#  FBgn0000008          1          0         12          0          0          0
#  FBgn0000014          0          0          0          0          0          0
#  FBgn0000015          0          0          0          0          0          0
#  FBgn0000017         56          0         49          0          0          0
#  ...                ...        ...        ...        ...        ...        ...
#  FBgn0287695          0          0          0          0          0          0
#  FBgn0287696          4          4         12          0          0          0
#  FBgn0287720          0          0          0          0          0          0
#  FBgn0287724          0          0          0          0          0        951
#  FBgn0287725         74         32        132          2          0          0
#
#               S20_file0  S21_file0  S22_file0
#  GeneID
#  FBgn0000003          2          5          0
#  FBgn0000008          0          0          0
#  FBgn0000014          0          0          0
#  FBgn0000015          0          0          0
#  FBgn0000017          0          0          0
#  ...                ...        ...        ...
#  FBgn0287695          0          0          0
#  FBgn0287696          0         10          0
#  FBgn0287720          0          0          0
#  FBgn0287724          0          0          0
#  FBgn0287725          2          0          0
#
#  [17580 rows x 22 columns],
#               S1_file1  S2_file1  S3_file1  S4_file1  S5_file1  S6_file1  \
#  GeneID
#  FBgn0260439         0         0         0         0         4         0
#  FBgn0000056         1         0         0         0         0         1
#  FBgn0031081         4        33        10        10        10        11
#  FBgn0031085        35       103        39        37        62        55
#  FBgn0062565         0         0         0         0         0         1
#  ...               ...       ...       ...       ...       ...       ...
#  FBgn0039656        10        31        11         7         8        15
#  FBgn0044048         0         0         0         0         0         0
#  FBgn0038034       392       415       153       187        79        77
#  FBgn0285938         0         0         0         0         0         0
#  FBgn0285963         9         8        58        82       237       135
#
#               S7_file1  S8_file1  S9_file1  S10_file1  S11_file1  S12_file1  \
#  GeneID
#  FBgn0260439        82         0         0          0          0          0
#  FBgn0000056         0         2         0          0          0          0
#  FBgn0031081        19        17         2          6         10         20
#  FBgn0031085        24        50        44        102         27         59
#  FBgn0062565         0         0         0          0          0          0
#  ...               ...       ...       ...        ...        ...        ...
#  FBgn0039656         0         4         4         14          5          5
#  FBgn0044048         0         0         0          0          0          0
#  FBgn0038034        41        51       125         99         61         92
#  FBgn0285938         0         0         0          2          0          0
#  FBgn0285963         1       374         0         54        133        113
#
#               S13_file1  S14_file1
#  GeneID
#  FBgn0260439         29          0
#  FBgn0000056          0          0
#  FBgn0031081        262          0
#  FBgn0031085          0          6
#  FBgn0062565          0          1
#  ...                ...        ...
#  FBgn0039656         65          0
#  FBgn0044048          0          0
#  FBgn0038034        272        300
#  FBgn0285938          0          0
#  FBgn0285963          0          0
#
#  [13843 rows x 14 columns],
#               S1_file2  S2_file2  S3_file2
#  GeneID
#  FBgn0000003         0         0         0
#  FBgn0000008      2811      1618      2026
#  FBgn0000014         1         0         0
#  FBgn0000015         6        10         2
#  FBgn0000017      2276      1198      1419
#  ...               ...       ...       ...
#  FBgn0267791      4631      3629      3114
#  FBgn0267792      1097       919       781
#  FBgn0267793         8         3        23
#  FBgn0267794         5         0         4
#  FBgn0267795      1992      1847      1408
#
#  [17559 rows x 3 columns],
#                                S_file3
#  GeneID
#  RR48301_transposable_element       14
#  RR48319_transposable_element        1
#  RR43685_transposable_element       21
#  FBgn0267431                     26030
#  RR48337_transposable_element        0
#  ...                               ...
#  FBgn0259864                        10
#  FBgn0085506                         7
#  FBgn0259870                         2
#  FBgn0085511                         0
#  Unc84                          223122
#
#  [23933 rows x 1 columns],
#                                S_file4
#  GeneID
#  RR48301_transposable_element       18
#  RR48319_transposable_element        1
#  RR43685_transposable_element       15
#  FBgn0267431                     21733
#  RR48337_transposable_element        0
#  ...                               ...
#  FBgn0259864                         7
#  FBgn0085506                         3
#  FBgn0259870                         4
#  FBgn0085511                         2
#  Unc84                          175032
#
#  [23933 rows x 1 columns],
#                                S_file5
#  GeneID
#  RR48301_transposable_element       15
#  RR48319_transposable_element        1
#  RR43685_transposable_element        5
#  FBgn0267431                     23431
#  RR48337_transposable_element        0
#  ...                               ...
#  FBgn0259864                        12
#  FBgn0085506                         6
#  FBgn0259870                         6
#  FBgn0085511                         0
#  Unc84                          215305
#
#  [23933 rows x 1 columns],
#                                S_file6
#  GeneID
#  RR48301_transposable_element       12
#  RR48319_transposable_element        0
#  RR43685_transposable_element        7
#  FBgn0267431                     25127
#  RR48337_transposable_element        0
#  ...                               ...
#  FBgn0259864                         6
#  FBgn0085506                         6
#  FBgn0259870                         6
#  FBgn0085511                         0
#  Unc84                          227058
#
#  [23933 rows x 1 columns],
#                                S_file7
#  GeneID
#  RR48301_transposable_element       19
#  RR48319_transposable_element        2
#  RR43685_transposable_element       13
#  FBgn0267431                     20789
#  RR48337_transposable_element        0
#  ...                               ...
#  FBgn0259864                         9
#  FBgn0085506                         2
#  FBgn0259870                         9
#  FBgn0085511                         0
#  Unc84                          130127
#
#  [23933 rows x 1 columns]]

# %%
merged_df = dataframes[0]
for df in dataframes[1:]:
    merged_df = pd.merge(merged_df, df, on='GeneID', how='inner')
merged_df
# Out:
#              S1_file0  S2_file0  S3_file0  S4_file0  S5_file0  S6_file0  \
# GeneID
# FBgn0000008       114       167       308       185        87         7
# FBgn0000014         0         0         0         0         0         0
# FBgn0000015         0         0         0         0         0         0
# FBgn0000017        71        84       176        12         0        87
# FBgn0000018         0         1         1         0         0         0
# ...               ...       ...       ...       ...       ...       ...
# FBgn0267728         2         0         0         0         0         0
# FBgn0267790        94       111        19         5         0        16
# FBgn0267791        45        39        32        38         0       156
# FBgn0267792         0         0         0         0         0         0
# FBgn0267795        18        31         0         0         0         0
#
#              S7_file0  S8_file0  S9_file0  S10_file0  ...  S13_file1  \
# GeneID                                                ...
# FBgn0000008        28        62       113         33  ...        180
# FBgn0000014         0         0         0          0  ...          0
# FBgn0000015         0         0         0          0  ...          0
# FBgn0000017        46        51        79        110  ...          0
# FBgn0000018         2         1         0          1  ...          0
# ...               ...       ...       ...        ...  ...        ...
# FBgn0267728         0         4         0          5  ...          0
# FBgn0267790         0        84         0          9  ...         14
# FBgn0267791         0        99        10         12  ...          0
# FBgn0267792         0         3         0          0  ...          0
# FBgn0267795        32         2         0          0  ...          0
#
#              S14_file1  S1_file2  S2_file2  S3_file2  S_file3  S_file4  \
